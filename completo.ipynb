# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:/Users/phill/projetos/Tech5/PEDE_PASSOS_DATASET_FIAP.csv', sep=';', encoding='utf-8')

# %%
df.shape # type: ignore
# Out:
# (1349, 69)

# %%
df.columns
# Out:
# Index(['INSTITUICAO_ENSINO_ALUNO_2020', 'NOME', 'IDADE_ALUNO_2020',
#        'ANOS_PM_2020', 'FASE_TURMA_2020', 'PONTO_VIRADA_2020', 'INDE_2020',
#        'INDE_CONCEITO_2020', 'PEDRA_2020', 'DESTAQUE_IEG_2020',
#        'DESTAQUE_IDA_2020', 'DESTAQUE_IPV_2020', 'IAA_2020', 'IEG_2020',
#        'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020', 'FASE_2021',
#        'TURMA_2021', 'INSTITUICAO_ENSINO_ALUNO_2021',
#        'SINALIZADOR_INGRESSANTE_2021', 'PEDRA_2021', 'INDE_2021', 'IAA_2021',
#        'IEG_2021', 'IPS_2021', 'IDA_2021', 'IPP_2021', 'REC_EQUIPE_1_2021',
#        'REC_EQUIPE_2_2021', 'REC_EQUIPE_3_2021', 'REC_EQUIPE_4_2021',
#        'PONTO_VIRADA_2021', 'IPV_2021', 'IAN_2021', 'NIVEL_IDEAL_2021',
#        'DEFASAGEM_2021', 'FASE_2022', 'TURMA_2022', 'ANO_INGRESSO_2022',
#        'BOLSISTA_2022', 'INDE_2022', 'CG_2022', 'CF_2022', 'CT_2022',
#        'PEDRA_2022', 'DESTAQUE_IEG_2022', 'DESTAQUE_IDA_2022',
#        'DESTAQUE_IPV_2022', 'IAA_2022', 'IEG_2022', 'IPS_2022', 'IDA_2022',
#        'NOTA_PORT_2022', 'NOTA_MAT_2022', 'NOTA_ING_2022', 'QTD_AVAL_2022',
#        'IPP_2022', 'REC_AVA_1_2022', 'REC_AVA_2_2022', 'REC_AVA_3_2022',
#        'REC_AVA_4_2022', 'INDICADO_BOLSA_2022', 'PONTO_VIRADA_2022',
#        'IPV_2022', 'IAN_2022', 'NIVEL_IDEAL_2022'],
#       dtype='object')

# %%
df.iloc[[1258]]
# Out:
#      INSTITUICAO_ENSINO_ALUNO_2020        NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 1258                          V202  ALUNO-1259             D108         D971
#
#      FASE_TURMA_2020 PONTO_VIRADA_2020 INDE_2020 INDE_CONCEITO_2020  \
# 1258            D207             D9600      D980            D9891/2
#
#      PEDRA_2020 DESTAQUE_IEG_2020  ... IPP_2022 REC_AVA_1_2022 REC_AVA_2_2022  \
# 1258   D9891/2A              D301  ...      NaN            NaN            NaN
#
#      REC_AVA_3_2022 REC_AVA_4_2022 INDICADO_BOLSA_2022 PONTO_VIRADA_2022  \
# 1258            NaN            NaN                 NaN               NaN
#
#      IPV_2022 IAN_2022  NIVEL_IDEAL_2022
# 1258      NaN      NaN               NaN
#
# [1 rows x 69 columns]

# %%
df = df.drop([1258], axis=0).reset_index(drop=True)

# %%
df.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1               11            2
# 1                           NaN  ALUNO-2              NaN          NaN
# 2                Escola Pública  ALUNO-3               12            2
# 3                Escola Pública  ALUNO-4               10            2
# 4                Escola Pública  ALUNO-5               10            1
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020          INDE_2020 INDE_CONCEITO_2020  \
# 0              2H               Não           7.883752                  B
# 1             NaN               NaN                NaN                NaN
# 2              3H               Não  7.856389666666666                  B
# 3              1D               Não           5.076252                  D
# 4              2M               Não           8.077085                  B
#
#   PEDRA_2020                                  DESTAQUE_IEG_2020  ...  \
# 0   Ametista  Seu destaque em 2020: A sua boa entrega das li...  ...
# 1        NaN                                                NaN  ...
# 2   Ametista  Seu destaque em 2020: A sua boa entrega das li...  ...
# 3    Quartzo  Ponto a melhorar em 2021: Melhorar a sua entre...  ...
# 4   Ametista  Seu destaque em 2020: A sua boa entrega das li...  ...
#
#    IPP_2022           REC_AVA_1_2022         REC_AVA_2_2022  \
# 0       NaN                      NaN                    NaN
# 1  5.625000  Mantido na Fase + Bolsa  Mantido na Fase atual
# 2       NaN                      NaN                    NaN
# 3  6.250000        Promovido de Fase  Mantido na Fase atual
# 4  6.458333    Mantido na Fase atual      Promovido de Fase
#
#           REC_AVA_3_2022 REC_AVA_4_2022 INDICADO_BOLSA_2022 PONTO_VIRADA_2022  \
# 0                    NaN            NaN                 NaN               NaN
# 1                    NaN            NaN                 Sim               Não
# 2                    NaN            NaN                 NaN               NaN
# 3      Promovido de Fase            NaN                 Não               Não
# 4  Mantido na Fase atual            NaN                 Não               Não
#
#    IPV_2022 IAN_2022      NIVEL_IDEAL_2022
# 0       NaN      NaN                   NaN
# 1  7.916665      5.0  Fase 2 (5º e 6º ano)
# 2       NaN      NaN                   NaN
# 3  8.055553      5.0  Fase 3 (7º e 8º ano)
# 4  7.833337      5.0  Fase 3 (7º e 8º ano)
#
# [5 rows x 69 columns]

# %%
cols = ['IAN_2020', 'IDA_2020', 'IEG_2020','IAA_2020', 'IPS_2020', 'IPP_2020', 'IPV_2020',
        'IAN_2021', 'IDA_2021', 'IEG_2021','IAA_2021', 'IPS_2021', 'IPP_2021', 'IPV_2021',
        'IAN_2022', 'IDA_2022', 'IEG_2022','IAA_2022', 'IPS_2022', 'IPP_2022', 'IPV_2022']

df[cols] = df[cols].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348 entries, 0 to 1347
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  727 non-null    object
#  1   NOME                           1348 non-null   object
#  2   IDADE_ALUNO_2020               727 non-null    object
#  3   ANOS_PM_2020                   727 non-null    object
#  4   FASE_TURMA_2020                727 non-null    object
#  5   PONTO_VIRADA_2020              701 non-null    object
#  6   INDE_2020                      727 non-null    object
#  7   INDE_CONCEITO_2020             727 non-null    object
#  8   PEDRA_2020                     727 non-null    object
#  9   DESTAQUE_IEG_2020              727 non-null    object
#  10  DESTAQUE_IDA_2020              727 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
#  12  IAA_2020                       727 non-null    float64
#  13  IEG_2020                       727 non-null    float64
#  14  IPS_2020                       727 non-null    float64
#  15  IDA_2020                       727 non-null    float64
#  16  IPP_2020                       727 non-null    float64
#  17  IPV_2020                       727 non-null    float64
#  18  IAN_2020                       727 non-null    float64
#  19  FASE_2021                      686 non-null    float64
#  20  TURMA_2021                     686 non-null    object
#  21  INSTITUICAO_ENSINO_ALUNO_2021  686 non-null    object
#  22  SINALIZADOR_INGRESSANTE_2021   686 non-null    object
#  23  PEDRA_2021                     686 non-null    object
#  24  INDE_2021                      686 non-null    object
#  25  IAA_2021                       686 non-null    float64
#  26  IEG_2021                       686 non-null    float64
#  27  IPS_2021                       686 non-null    float64
#  28  IDA_2021                       686 non-null    float64
#  29  IPP_2021                       686 non-null    float64
#  30  REC_EQUIPE_1_2021              686 non-null    object
#  31  REC_EQUIPE_2_2021              686 non-null    object
#  32  REC_EQUIPE_3_2021              686 non-null    object
#  33  REC_EQUIPE_4_2021              686 non-null    object
#  34  PONTO_VIRADA_2021              686 non-null    object
#  35  IPV_2021                       686 non-null    float64
#  36  IAN_2021                       686 non-null    float64
#  37  NIVEL_IDEAL_2021               686 non-null    object
#  38  DEFASAGEM_2021                 686 non-null    float64
#  39  FASE_2022                      862 non-null    float64
#  40  TURMA_2022                     862 non-null    object
#  41  ANO_INGRESSO_2022              862 non-null    float64
#  42  BOLSISTA_2022                  862 non-null    object
#  43  INDE_2022                      862 non-null    float64
#  44  CG_2022                        862 non-null    float64
#  45  CF_2022                        862 non-null    float64
#  46  CT_2022                        862 non-null    float64
#  47  PEDRA_2022                     862 non-null    object
#  48  DESTAQUE_IEG_2022              862 non-null    object
#  49  DESTAQUE_IDA_2022              862 non-null    object
#  50  DESTAQUE_IPV_2022              862 non-null    object
#  51  IAA_2022                       862 non-null    float64
#  52  IEG_2022                       862 non-null    float64
#  53  IPS_2022                       862 non-null    float64
#  54  IDA_2022                       862 non-null    float64
#  55  NOTA_PORT_2022                 860 non-null    float64
#  56  NOTA_MAT_2022                  860 non-null    float64
#  57  NOTA_ING_2022                  285 non-null    float64
#  58  QTD_AVAL_2022                  862 non-null    float64
#  59  IPP_2022                       862 non-null    float64
#  60  REC_AVA_1_2022                 862 non-null    object
#  61  REC_AVA_2_2022                 862 non-null    object
#  62  REC_AVA_3_2022                 626 non-null    object
#  63  REC_AVA_4_2022                 285 non-null    object
#  64  INDICADO_BOLSA_2022            862 non-null    object
#  65  PONTO_VIRADA_2022              862 non-null    object
#  66  IPV_2022                       862 non-null    float64
#  67  IAN_2022                       862 non-null    float64
#  68  NIVEL_IDEAL_2022               862 non-null    object
# dtypes: float64(33), object(36)
# memory usage: 726.8+ KB

# %%
df_2020 = df[['IAN_2020',
              'IDA_2020',
              'IEG_2020',
              'IAA_2020',
              'IPS_2020',
              'IPP_2020',
              'IPV_2020']]

df_2021 = df[['IAN_2021',
              'IDA_2021',
              'IEG_2021',
              'IAA_2021',
              'IPS_2021',
              'IPP_2021',
              'IPV_2021']]

df_2022 = df[['IAN_2022',
              'IDA_2022',
              'IEG_2022',
              'IAA_2022',
              'IPS_2022',
              'IPP_2022',
              'IPV_2022']]

# %%
def rename_columns(df, ano):
    df.rename(columns={f'IAN_{ano}': 'IAN',
                       f'IDA_{ano}': 'IDA',
                       f'IEG_{ano}': 'IEG',
                       f'IAA_{ano}': 'IAA',
                       f'IPS_{ano}': 'IPS',
                       f'IPP_{ano}': 'IPP',
                       f'IPV_{ano}': 'IPV'}, inplace=True)

# %%
rename_columns(df_2020, '2020')
rename_columns(df_2021, '2021')
rename_columns(df_2022, '2022')

# %%
df_2020['Ano'] = '2020'
df_2021['Ano'] = '2021'
df_2022['Ano'] = '2022'

# %%
df_indicadores = pd.concat([df_2020, df_2021, df_2022], axis=0, ignore_index=True)

# %%
df_indicadores
# Out:
#        IAN  IDA       IEG      IAA    IPS      IPP       IPV   Ano
# 0     10.0  7.0  8.700000  8.50002  7.500  5.93750  7.750000  2020
# 1      NaN  NaN       NaN      NaN    NaN      NaN       NaN  2020
# 2     10.0  5.5  8.900000  7.91667  7.500  8.12500  8.111113  2020
# 3      5.0  0.0  4.100000  8.00002  6.875  7.18750  7.750000  2020
# 4     10.0  7.5  8.000000  7.50002  7.500  8.43750  8.166665  2020
# ...    ...  ...       ...      ...    ...      ...       ...   ...
# 4039   NaN  NaN       NaN      NaN    NaN      NaN       NaN  2022
# 4040   5.0  9.0  9.031839  9.00002  7.500  5.62500  9.083340  2022
# 4041   NaN  NaN       NaN      NaN    NaN      NaN       NaN  2022
# 4042   5.0  5.9  9.178030  8.33334  5.625  6.71875  5.833328  2022
# 4043   5.0  4.5  7.540114  7.91667  7.500  7.50000  5.999993  2022
#
# [4044 rows x 8 columns]

# %%
df.describe()
# Out:
#          IAA_2020    IEG_2020    IPS_2020    IDA_2020    IPP_2020    IPV_2020  \
# count  727.000000  727.000000  727.000000  727.000000  727.000000  727.000000
# mean     8.368882    7.681155    6.737448    6.322260    7.067859    7.242243
# std      1.727980    2.382122    1.374011    2.960073    1.988054    1.775110
# min      0.000000    0.000000    2.500000    0.000000    0.000000    0.000000
# 25%      7.958350    6.600000    5.625000    4.666667    6.953125    6.916665
# 50%      8.750010    8.500000    7.500000    7.000000    7.500000    7.583335
# 75%      9.166680    9.500000    7.500000    8.666667    8.125000    8.055557
# max     10.000020   10.000000   10.000000   10.000000   10.000000   10.000010
#
#          IAN_2020   FASE_2021    IAA_2021    IEG_2021  ...    IEG_2022  \
# count  727.000000  686.000000  686.000000  686.000000  ...  862.000000
# mean     7.431224    2.276968    8.153499    6.822595  ...    7.880728
# std      2.556944    1.798368    2.193629    2.458627  ...    1.649023
# min      2.500000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      5.000000    1.000000    7.900000    5.300000  ...    6.999971
# 50%      5.000000    2.000000    8.800000    7.200000  ...    8.312179
# 75%     10.000000    3.000000    9.500000    8.800000  ...    9.102970
# max     10.000000    7.000000   10.000000   10.000000  ...   10.000000
#
#          IPS_2022    IDA_2022  NOTA_PORT_2022  NOTA_MAT_2022  NOTA_ING_2022  \
# count  862.000000  862.000000      860.000000     860.000000     285.000000
# mean     6.901102    6.070688        5.796318       6.306628       5.839942
# std      1.070202    2.059346        2.422292       2.092551       2.992093
# min      2.500000    0.000000        0.000000       0.000000       0.000000
# 25%      6.250000    4.750000        4.316667       5.166667       3.500000
# 50%      7.500000    6.333333        6.000000       6.650000       6.266667
# 75%      7.500000    7.583333        7.833333       7.833333       8.500000
# max     10.000000    9.916667       10.000000      10.000000      10.000000
#
#        QTD_AVAL_2022    IPP_2022    IPV_2022    IAN_2022
# count     862.000000  862.000000  862.000000  862.000000
# mean        3.056845    6.299364    7.247953    6.421114
# std         0.775806    1.135510    1.098548    2.387816
# min         2.000000    0.000000    2.500010    2.500000
# 25%         2.000000    5.625000    6.722220    5.000000
# 50%         3.000000    6.250000    7.333335    5.000000
# 75%         4.000000    7.031250    7.916665   10.000000
# max         4.000000    9.218750   10.000010   10.000000
#
# [8 rows x 33 columns]

# %% [markdown]
# ### **1. Adequação ao nível (IAN): Qual é o perfil geral de defasagem dos alunos (IAN) e como ele evolui ao longo do ano?**

# %%
IAN_anos = df_indicadores[['Ano', 'IAN']]

# %%
IAN_anos['IAN'].replace({10.0: 'Em fase', 5.0: 'Moderada', 2.5: 'Severa'}, inplace=True)

# %%
IAN_anos = IAN_anos.groupby('Ano').value_counts().reset_index().sort_values(by=['Ano', 'IAN'])

# %%
cores_set1 = sns.color_palette('Set1', n_colors=9)

cores_personalizadas = cores_set1[2::-1] + cores_set1[3:]

plt.figure(figsize=(10, 6))
ax = sns.barplot(
    x='Ano',
    y='count',
    hue='IAN',
    data=IAN_anos,
    palette=cores_personalizadas
)

for container in ax.containers:
    ax.bar_label(container, padding=3)

plt.title('Qual é o perfil geral de defasagem dos alunos (IAN) \n e como ele evolui ao longo dos anos? \n', fontsize=16)
plt.xlabel(None)
plt.ylabel(None)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Com base nos dados apresentados, o perfil de defasagem dos alunos (IAN) demonstra uma deterioração progressiva entre 2020 e 2022. Enquanto em 2020 havia um equilíbrio entre alunos "Em fase" (359) e com defasagem "Moderada" (357), os anos seguintes mostram uma queda acentuada no grupo que está no nível adequado, reduzindo-se para 259 alunos em 2022. Em contrapartida, a defasagem Moderada tornou-se predominante, saltando de 357 para 575 alunos no período. Além disso, embora a defasagem "Severa" tenha se mantido baixa e estável nos dois primeiros anos, houve um aumento preocupante de 180% nessa categoria em 2022 (passando de 10 para 28 alunos), indicando que o desafio educacional se intensificou tanto em volume quanto em gravidade ao longo do tempo.

# %%
total_anos = IAN_anos.groupby('Ano')['count'].sum()

# %%
IAN_anos = IAN_anos.merge(total_anos, on='Ano', how='left', suffixes=('', '_total'))

# %%
IAN_anos['pct_change'] = (IAN_anos.groupby('IAN')['count'].pct_change() * 100).round(2)

# %%
IAN_anos['prop_ano'] = IAN_anos['count'] / IAN_anos['count_total']

# %% [markdown]
# prop_Ano é a fração que cada IAN representa do total daquele Ano, garantindo comparabilidade mesmo se o total anual mudar.

# %%
IAN_anos['pct_change_prop'] = (IAN_anos.groupby('IAN')['prop_ano'].pct_change() * 100).round(2)

# %%
IAN_anos['diff_anual'] = IAN_anos.groupby('IAN')['count'].diff()

# %%
IAN_anos[['Ano', 'IAN', 'count', 'pct_change', 'pct_change_prop', 'diff_anual']].set_index('Ano')
# Out:
#            IAN  count  pct_change  pct_change_prop  diff_anual
# Ano
# 2020   Em fase    359         NaN              NaN         NaN
# 2020  Moderada    357         NaN              NaN         NaN
# 2020    Severa     11         NaN              NaN         NaN
# 2021   Em fase    266      -25.91           -21.48       -93.0
# 2021  Moderada    410       14.85            21.71        53.0
# 2021    Severa     10       -9.09            -3.66        -1.0
# 2022   Em fase    259       -2.63           -22.51        -7.0
# 2022  Moderada    575       40.24            11.61       165.0
# 2022    Severa     28      180.00           122.83        18.0

# %% [markdown]
# ### **2. Desempenho acadêmico (IDA): O desempenho acadêmico médio (IDA) está melhorando, estagnado ou caindo ao longo das fases e anos?**

# %% [markdown]
# Média do IDA ao longo dos anos

# %%
df_indicadores[['IDA', 'Ano']].groupby(by='Ano').mean().round(3)
# Out:
#         IDA
# Ano
# 2020  6.322
# 2021  5.426
# 2022  6.071

# %% [markdown]
# Diferença das médias ao longo dos anos

# %%
df_indicadores[['IDA', 'Ano']].groupby('Ano').mean().diff().round(3)
# Out:
#         IDA
# Ano
# 2020    NaN
# 2021 -0.896
# 2022  0.645

# %% [markdown]
# Porcentagem da diferença ao longo dos anos

# %%
(df_indicadores[['IDA', 'Ano']].groupby('Ano').mean().pct_change() * 100).round(2)
# Out:
#         IDA
# Ano
# 2020    NaN
# 2021 -14.18
# 2022  11.88

# %% [markdown]
# Média central

# %%
df_indicadores['IDA'].mean().round(3)
# Out:
# np.float64(5.957)

# %% [markdown]
# Desvio Padrão da média central

# %%
df_indicadores[['IDA', 'Ano']].groupby('Ano').mean().std().round(3)
# Out:
# IDA    0.462
# dtype: float64

# %% [markdown]
# ### **3. Engajamento nas atividades (IEG): O grau de engajamento dos alunos (IEG) tem relação direta com seus indicadores de desempenho (IDA) e do ponto de virada (IPV)?**

# %% [markdown]
# Correlação IEG x IDA

# %%
(df_indicadores['IEG'].corr(df_indicadores['IDA']) * 100).round(2)
# Out:
# np.float64(56.48)

# %% [markdown]
# Correlação IEG x IPV

# %%
(df_indicadores['IEG'].corr(df_indicadores['IPV']) * 100).round(2)
# Out:
# np.float64(51.99)

# %%
import statsmodels.api as sm

def resumo_executivo_regressao(df, dependente):
    # Limpeza e Modelagem
    df_limpo = df[['IEG', dependente]].dropna()
    X = sm.add_constant(df_limpo['IEG'])
    y = df_limpo[dependente]
    modelo = sm.OLS(y, X).fit()
    
    # Extração dos indicadores-chave
    r2 = modelo.rsquared
    coef_ieg = modelo.params['IEG']
    p_value = modelo.pvalues['IEG']
    intercepto = modelo.params['const']
    
    # Impressão formatada para interpretação
    print(f"--- ANÁLISE EXECUTIVA: IEG vs {dependente} ---")
    print(f"1. PODER DE EXPLICAÇÃO (R²): {r2:.2%}")
    print(f"   O engajamento explica {r2:.2%} da variação de {dependente}.")
    
    print(f"\n2. IMPACTO (Coeficiente): {coef_ieg:.4f}")
    print(f"   Cada +1 ponto em IEG resulta em uma mudança de {coef_ieg:.4f} em {dependente}.")
    
    status_p = "SIGNIFICATIVA" if p_value < 0.05 else "NÃO SIGNIFICATIVA"
    print(f"\n3. CONFIANÇA ESTATÍSTICA (P-Value): {p_value:.4f} ({status_p})")
    
    print(f"\n4. EQUAÇÃO PREDITIVA:")
    print(f"   {dependente} = {intercepto:.2f} + ({coef_ieg:.2f} * IEG)")
    print("-" * 45 + "\n")

# %%
resumo_executivo_regressao(df_indicadores, 'IDA')
# Out:
# --- ANÁLISE EXECUTIVA: IEG vs IDA ---
# 1. PODER DE EXPLICAÇÃO (R²): 31.90%
#    O engajamento explica 31.90% da variação de IDA.
#
# 2. IMPACTO (Coeficiente): 0.6228
#    Cada +1 ponto em IEG resulta em uma mudança de 0.6228 em IDA.
#
# 3. CONFIANÇA ESTATÍSTICA (P-Value): 0.0000 (SIGNIFICATIVA)
#
# 4. EQUAÇÃO PREDITIVA:
#    IDA = 1.29 + (0.62 * IEG)
# ---------------------------------------------

# %% [markdown]
# **Sim, existe uma relação direta, positiva e estatisticamente comprovada.**
# O engajamento dos alunos (IEG) é um motor fundamental para o desempenho acadêmico (IDA). A análise revela que a relação entre essas variáveis não é fruto do acaso, apresentando uma confiança estatística total ($p < 0,001$).
#
# **Relação de Causa e Efeito:**
# - O engajamento atua como um preditor direto da nota. Para cada ponto que um aluno sobe em sua escala de engajamento, espera-se um aumento médio de 0,62 em seu indicador de desempenho (IDA).
#
# - Peso do Engajamento: O IEG sozinho consegue explicar quase 32% de tudo o que acontece com as notas dos alunos. Isso significa que, em um cenário escolar complexo, quase um terço do sucesso acadêmico pode ser atribuído diretamente ao nível de participação e dedicação do estudante.
#
# - Consistência Pedagógica: A equação preditiva ($IDA = 1,29 + 0,62 \times IEG$) mostra que o engajamento "potencializa" o desempenho. Mesmo alunos que partem de uma base comum (o intercepto de 1,29) dependem do crescimento do IEG para atingir patamares de aprovação e excelência.Conclusão: O investimento em estratégias para elevar o engajamento terá um retorno mensurável e direto na melhora dos indicadores de desempenho da instituição.

# %%
resumo_executivo_regressao(df_indicadores, 'IPV')
# Out:
# --- ANÁLISE EXECUTIVA: IEG vs IPV ---
# 1. PODER DE EXPLICAÇÃO (R²): 27.03%
#    O engajamento explica 27.03% da variação de IPV.
#
# 2. IMPACTO (Coeficiente): 0.3548
#    Cada +1 ponto em IEG resulta em uma mudança de 0.3548 em IPV.
#
# 3. CONFIANÇA ESTATÍSTICA (P-Value): 0.0000 (SIGNIFICATIVA)
#
# 4. EQUAÇÃO PREDITIVA:
#    IPV = 4.63 + (0.35 * IEG)
# ---------------------------------------------

# %% [markdown]
# | Métrica                     | IDA (Desempenho Acadêmico) | IPV (Ponto de Virada) |
# |----------------------------|---------------------------|-----------------------|
# | Poder de Explicação (R²)   | 31,90%                    | 27,03%                |
# | Impacto Direto (Coeficiente)| 0,6228                    | 0,3548                |
# | Ponto de Partida (Intercepto) | 1,29                   | 4,63                  |
# | Confiança (P-Value)        | 0,0000 (Significativo)    | 0,0000 (Significativo)|
# | Equação Preditiva          | IDA = 1,29 + 0,62 × IEG   | IPV = 4,63 + 0,35 × IEG |

# %% [markdown]
# **Interpretação da Comparação**
# - O IDA é mais "sensível" ao engajamento: O coeficiente do IDA ($0,62$) é quase o dobro do IPV ($0,35$). Isso indica que o esforço e engajamento do aluno se refletem de forma muito mais imediata e intensa nas notas do que na mudança de sua trajetória de longo prazo.
#
# - O IPV tem uma base mais estável: Note que o ponto de partida do IPV ($4,63$) é muito mais alto que o do IDA ($1,29$). Isso sugere que o "Ponto de Virada" depende de uma base socioeducacional mais sólida, enquanto o desempenho nas notas é mais volátil e dependente do engajamento presente.
#
# - Explicação de Variância: O engajamento explica melhor o desempenho atual ($31,9\%$) do que a virada de trajetória ($27\%$). Isso faz sentido pedagógico: "virar a chave" (IPV) é um processo mais complexo que envolve fatores além do engajamento, como resiliência e suporte externo.

# %% [markdown]
# ### **4. Autoavaliação (IAA): As percepções dos alunos sobre si mesmos (IAA) são coerentes com seu desempenho real (IDA) e engajamento (IEG)?**

# %% [markdown]
# #### Correlação IAA x IDA

# %%
(df_indicadores['IAA'].corr(df_indicadores['IDA']) * 100).round(2)
# Out:
# np.float64(26.49)

# %% [markdown]
# #### Correlação IAA x IEG

# %%
(df_indicadores['IAA'].corr(df_indicadores['IEG']) * 100).round(2)
# Out:
# np.float64(32.74)

# %%
def plot_quadrantes(x_col, y_col, df):
    plt.figure(figsize=(11, 6))
    
    sns.scatterplot(data=df, x=x_col, y=y_col, alpha=0.6, s=100)
    
    # Linhas de média para criar os quadrantes
    mean_x = df[x_col].mean()
    mean_y = df[y_col].mean()
    plt.axvline(mean_x, color='red', linestyle='-', alpha=0.8)
    plt.axhline(mean_y, color='red', linestyle='-', alpha=0.8)
    
    # Títulos e labels
    plt.title(f'Análise de Coerência: {x_col} vs {y_col}', fontsize=14, pad=20)
    plt.xlabel(f'{x_col} (Percepção)', fontsize=12)
    plt.ylabel(f'{y_col} (Realidade)', fontsize=12)
    
    # Lado Direito
    plt.text(1.02, 0.95, 'Coerentes (Alto)', color='green', transform=plt.gca().transAxes, va='top')
    plt.text(1.02, 0.05, 'Superestimados', color='red', transform=plt.gca().transAxes, va='bottom')
    
    # Lado Esquerdo
    plt.text(-0.20, 0.95, 'Subestimados', color='red', transform=plt.gca().transAxes, va='top')
    plt.text(-0.20, 0.05, 'Coerentes (Baixo)', color='green', transform=plt.gca().transAxes, va='bottom')
    
    plt.grid(True, alpha=0.3)
    
    plt.subplots_adjust(right=0.85, left=0.20) 
    plt.show()

# %%
plot_quadrantes('IAA', 'IDA', df_indicadores)

# %% [markdown]
# A grande maioria dos pontos está concentrada entre os valores 8 e 10 do IAA. Isso indica que a maioria dos alunos tem uma autopercepção muito elevada, independentemente da nota real.
#
# **Análise dos Quadrantes**
# - Superestimados (Canto Inferior Direito): Há uma densidade altíssima de alunos aqui. Eles avaliaram a si mesmos com notas próximas a 10, mas possuem IDA (desempenho real) variando de 0 a 4. Este grupo está em "cegueira cognitiva", não percebendo suas dificuldades.
#
# - Subestimados (Canto Superior Esquerdo): Note que existem vários pontos no eixo 0 do IAA com notas (IDA) entre 6 e 9. São alunos que não possuem confiança nenhuma em seu potencial, mas apresentam resultados reais excelentes.
#
# - Coerentes (Baixo): Existe uma linha vertical no IAA 0. Muitos alunos se deram nota zero e realmente tiraram notas baixas. Embora o desempenho seja ruim, a percepção deles sobre a própria situação é realista.
#
# Não há coerência substancial. Observa-se um forte viés de sobrevalorização, onde uma parcela significativa de alunos atribui a si mesma a nota máxima de percepção (IAA 10), enquanto seu desempenho real (IDA) ocupa toda a escala de 0 a 10. Além disso, existe um grupo notável de alunos com subestimação severa, que possuem bom desempenho acadêmico apesar de uma autopercepção nula.

# %% [markdown]
# ### **5. Aspectos psicossociais (IPS): Há padrões psicossociais (IPS) que antecedem quedas de desempenho acadêmico ou de engajamento?**

# %%
df['DELTA_IDA_2021'] = df['IDA_2021'] - df['IDA_2020']
df['DELTA_IDA_2022'] = df['IDA_2022'] - df['IDA_2021']
df['DELTA_IEG_2021'] = df['IEG_2021'] - df['IEG_2020']
df['DELTA_IEG_2022'] = df['IEG_2022'] - df['IEG_2021']

# %% [markdown]
# #### Correlação do IPS 2020 x IDA 2021

# %%
(df['IPS_2020'].corr(df['DELTA_IDA_2021']) * 100).round(2)
# Out:
# np.float64(1.27)

# %% [markdown]
# #### Correlação do IPS 2021 x IDA 2022

# %%
(df['IPS_2021'].corr(df['DELTA_IDA_2022']) * 100).round(2)
# Out:
# np.float64(0.47)

# %% [markdown]
# #### Correlação do IPS 2020 x IEG 2021

# %%
(df['IPS_2020'].corr(df['DELTA_IEG_2021']) * 100).round(2)
# Out:
# np.float64(6.76)

# %% [markdown]
# #### Correlação do IPS 2021 x IEG 2022

# %%
(df['IPS_2021'].corr(df['DELTA_IEG_2022']) * 100).round(2)
# Out:
# np.float64(-5.26)

# %% [markdown]
# As correlações entre $1,27\%$ e $-5,26\%$ indicam que o IPS não é um "motor" que empurra a nota para cima ou para baixo de forma proporcional e constante.

# %% [markdown]
# #### Médias por categoria de IPS
#
# ![image.png](attachment:image.png)

# %%
def categoria_ips(df, ano):
    categ_ips = [
        (df[f'IPS_{ano}'] >= 0) & (df[f'IPS_{ano}'] <= 2.5),
        (df[f'IPS_{ano}'] > 2.5) & (df[f'IPS_{ano}'] <= 5),
        (df[f'IPS_{ano}'] > 5) & (df[f'IPS_{ano}'] <= 7.5),
        (df[f'IPS_{ano}'] > 7.5)
    ]

    valores = [
        'D. Em atendimento terapêutico',
        'C. Interações desfuncionais',
        'B. Boa adequação geral',
        'A. Interações funcionais'
    ]

    df[f'categoria_IPS_{ano}'] = np.select(
        condlist=categ_ips,
        choicelist=valores,
        default='Sem categoria'
    )

# %%
categoria_ips(df, 2020)
categoria_ips(df, 2021)

# %%
media_IDA_2021_por_categ = df.groupby(by='categoria_IPS_2020')['DELTA_IDA_2021'].mean()
media_IDA_2021_por_categ
# Out:
# categoria_IPS_2020
# A. Interações funcionais        -0.861905
# B. Boa adequação geral          -1.545030
# C. Interações desfuncionais     -1.559574
# D. Em atendimento terapêutico   -2.355556
# Sem categoria                         NaN
# Name: DELTA_IDA_2021, dtype: float64

# %%
media_IDA_2022_por_categ = df.groupby(by='categoria_IPS_2021')['DELTA_IDA_2022'].mean()
media_IDA_2022_por_categ
# Out:
# categoria_IPS_2021
# A. Interações funcionais         0.875253
# B. Boa adequação geral           0.312925
# C. Interações desfuncionais      0.606566
# D. Em atendimento terapêutico    0.490556
# Sem categoria                         NaN
# Name: DELTA_IDA_2022, dtype: float64

# %%
plot_df = pd.DataFrame({
    'media_IDA_2021': media_IDA_2021_por_categ.values,
    'media_IDA_2022': media_IDA_2022_por_categ.values,
}, index=media_IDA_2021_por_categ.index)

plot_df = plot_df.reset_index(names='Categoria')
plot_df = plot_df.melt(id_vars='Categoria', var_name='Indicador_Ano', value_name='Media')
plot_df = plot_df[plot_df['Categoria'] != 'Sem categoria']

legend_map = {
    'media_IDA_2021': 'Média IDA 2021',
    'media_IDA_2022': 'Média IDA 2022'
}
plot_df['Indicador_Ano'] = plot_df['Indicador_Ano'].map(legend_map)

plt.figure(figsize=(12, 8))
ax = sns.barplot(data=plot_df, x='Categoria', y='Media', hue='Indicador_Ano', palette='Set1')

for container in ax.containers:
    ax.bar_label(container, padding=3, label_type='center', fmt='%.2f', color='white')

plt.title('Médias por categoria IPS (2021-2022)', fontsize=16)
plt.xticks(rotation=0)
plt.ylabel('Média')
plt.legend(title='Indicador', loc='lower left')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Apesar da baixa correlação o IPS pode funcionar como um indicador de risco.
#
# Ao olhar para as médias por categoria, o padrão é nítido:
#
# - Efeito de Queda (2020-2021): Alunos na Categoria D (Em atendimento terapêutico) tiveram uma queda de desempenho (-2,35) quase três vezes maior do que os alunos da Categoria A (-0,86).
#
# - Efeito de Recuperação (2021-2022): Quando o cenário foi de melhora, os alunos da Categoria A conseguiram subir sua média em 0,87, enquanto os da Categoria D subiram apenas 0,49.
#
# **Conclusão:** O padrão psicossocial baixo (C e D) antecede quedas mais profundas em momentos de crise e dificulta a recuperação em momentos de melhora. O IPS não é um previsor de nota, mas é um previsor de resiliência.

# %%
media_IEG_2021_por_categ = df.groupby(by='categoria_IPS_2020')['DELTA_IEG_2021'].mean()
media_IEG_2021_por_categ
# Out:
# categoria_IPS_2020
# A. Interações funcionais        -0.978571
# B. Boa adequação geral          -1.536446
# C. Interações desfuncionais     -2.059574
# D. Em atendimento terapêutico   -1.033333
# Sem categoria                         NaN
# Name: DELTA_IEG_2021, dtype: float64

# %%
media_IEG_2022_por_categ = df.groupby(by='categoria_IPS_2021')['DELTA_IEG_2022'].mean()
media_IEG_2022_por_categ
# Out:
# categoria_IPS_2021
# A. Interações funcionais         1.358547
# B. Boa adequação geral           0.522217
# C. Interações desfuncionais      0.949361
# D. Em atendimento terapêutico    0.662179
# Sem categoria                         NaN
# Name: DELTA_IEG_2022, dtype: float64

# %% [markdown]
# Os dados do IEG 2021 mostram que a Categoria C (Interações desfuncionais) teve a maior queda de engajamento (-2,05). Isso sugere que o comportamento social/emocional instável (Categoria C) afeta primeiro a vontade de participar (Engajamento) para depois atingir a nota (Desempenho).

# %% [markdown]
# ### **6. Aspectos psicopedagógicos (IPP): As avaliações psicopedagógicas (IPP) confirmam ou contradizem a defasagem identificada pelo IAN?**

# %%
def categoria_ipp(df, ano):
    categ_ipp = [
        (df[f'IPP_{ano}'] >= 0) & (df[f'IPP_{ano}'] <= 2.5),
        (df[f'IPP_{ano}'] > 2.5) & (df[f'IPP_{ano}'] <= 5),
        (df[f'IPP_{ano}'] > 5) & (df[f'IPP_{ano}'] <= 7.5),
        (df[f'IPP_{ano}'] > 7.5)
    ]

    valores = [
        'D. Em atendimento terapêutico',
        'C. Interações desfuncionais',
        'B. Boa adequação geral',
        'A. Interações funcionais'
    ]

    df[f'categoria_IPP_{ano}'] = np.select(
        condlist=categ_ipp,
        choicelist=valores,
        default='Sem categoria'
    )

# %%
categoria_ipp(df, 2020)
categoria_ipp(df, 2021)
categoria_ipp(df, 2022)

# %%
categoria_ipp = pd.concat([df['categoria_IPP_2020'], df['categoria_IPP_2021'], df['categoria_IPP_2022']])

# %%
df_indicadores = pd.concat([df_indicadores.reset_index(drop=True), categoria_ipp.reset_index(drop=True)], axis=1)

# %%
df_indicadores.rename(columns={0: 'CATEG_IPP'}, inplace=True)

# %%
df_indicadores['CATEG_IAN'] = df_indicadores['IAN'].replace({10.0: 'Em fase', 5.0: 'Moderada', 2.5: 'Severa'})

# %% [markdown]
# #### Correlação IAN x IPP

# %%
df_indicadores['IAN'].corr(df_indicadores['IPP'])
# Out:
# np.float64(0.05258247352633372)

# %% [markdown]
# O fato de um aluno apresentar defasagem de nível (IAN baixo) não tem poder preditivo sobre o seu estado psicopedagógico (IPP). São dimensões que avaliam aspectos totalmente distintos da realidade do estudante.

# %%
matriz_contingencia = pd.crosstab(df_indicadores['CATEG_IPP'], df_indicadores['CATEG_IAN'], dropna=True)
matriz_contingencia
# Out:
# CATEG_IAN                      Em fase  Moderada  Severa
# CATEG_IPP
# A. Interações funcionais           388       442      13
# B. Boa adequação geral             422       781      30
# C. Interações desfuncionais         29        88       6
# D. Em atendimento terapêutico       45        31       0

# %%
matriz_percentual = (pd.crosstab(df_indicadores['CATEG_IPP'], df_indicadores['CATEG_IAN'], normalize='all') * 100).round(2)
matriz_percentual
# Out:
# CATEG_IAN                      Em fase  Moderada  Severa
# CATEG_IPP
# A. Interações funcionais         17.05     19.43    0.57
# B. Boa adequação geral           18.55     34.33    1.32
# C. Interações desfuncionais       1.27      3.87    0.26
# D. Em atendimento terapêutico     1.98      1.36    0.00

# %% [markdown]
# A matriz revela que a maioria dos alunos com atraso escolar possui, na verdade, um ótimo perfil psicopedagógico.
#
# **O "Potencial Oculto" na Defasagem Moderada:** Dos alunos classificados com defasagem "Moderada" no IAN, a grande maioria está nas categorias A (442 alunos) e B (781 alunos) do IPP. Isso representa aproximadamente 53,7% da amostra total (19,43% + 34,33%). Ou seja, o IPP contradiz a defasagem ao mostrar que esses alunos possuem "Interações Funcionais" ou "Boa Adequação Geral".
#
# **Baixa Concordância na Defasagem Severa:** No grupo de defasagem "Severa", nenhum aluno (0,00%) foi classificado como necessitando de "Atendimento Terapêutico" (IPP D). Pelo contrário, a maioria desses alunos severamente defasados academicamente possui perfis de "Interações Funcionais" ou "Boa Adequação" (Categorias A e B).
#
# **Concordância na "Em Fase":** Apenas no grupo "Em fase" nota-se um equilíbrio, onde 388 alunos (17,05%) e 422 alunos (18,55%) confirmam a adequação acadêmica com uma boa adequação psicopedagógica.
#
# Os dados demonstram que o IPP **contradiz** a defasagem do IAN. A correlação desprezível (0,052) e a alta concentração de alunos com defasagem acadêmica (Moderada/Severa) que apresentam indicadores psicopedagógicos de alta funcionalidade (Categorias A e B) sugerem que o atraso escolar não está vinculado a impedimentos cognitivos, comportamentais ou sociais mensurados pelo IPP. Isso indica que a defasagem medida pelo IAN provavelmente decorre de fatores externos ao desenvolvimento individual do aluno, como histórico de acesso escolar ou vulnerabilidades socioeconômicas anteriores.

# %% [markdown]
# ### **7. Ponto de virada (IPV): Quais comportamentos - acadêmicos, emocionais ou de engajamento - mais influenciam o IPV ao longo do tempo?**

# %%
cols_IPV_2020 = ['IPV_2020', 'IDA_2020', 'IEG_2020', 'IPS_2020', 'IPP_2020', 'IAA_2020']
cols_IPV_2021 = ['IPV_2021', 'IDA_2021', 'IEG_2021', 'IPS_2021', 'IPP_2021', 'IAA_2021']
cols_IPV_2022 = ['IPV_2022', 'IDA_2022', 'IEG_2022', 'IPS_2022', 'IPP_2022', 'IAA_2022']

def preparar_df_ipv(df_orig, colunas):
    colunas_existentes = [c for c in colunas if c in df_orig.columns]
    temp = df_orig[colunas_existentes].copy()
    for col in temp.columns:
        temp[col] = pd.to_numeric(temp[col], errors='coerce')
    temp.columns = [c.split('_')[0] for c in temp.columns]
    return temp

df_2020_ipv = preparar_df_ipv(df, cols_IPV_2020)
df_2021_ipv = preparar_df_ipv(df, cols_IPV_2021)
df_2022_ipv = preparar_df_ipv(df, cols_IPV_2022)

df_analise_ipv = pd.concat([df_2020_ipv, df_2021_ipv, df_2022_ipv], axis=0).dropna()

correlacoes_ipv = df_analise_ipv.corr()['IPV'].sort_values(ascending=False)
print("--- O que mais correlaciona com o Ponto de Virada (IPV)? ---")
print(correlacoes_ipv)

X_ipv = df_analise_ipv[['IDA', 'IEG', 'IPS', 'IPP', 'IAA']]
y_ipv = df_analise_ipv['IPV']
X_ipv = sm.add_constant(X_ipv)

modelo_ipv = sm.OLS(y_ipv, X_ipv).fit()

print("\n--- PESO DOS COMPORTAMENTOS NO IPV ---")
print(f"R-quadrado: {modelo_ipv.rsquared:.2%}")
print(modelo_ipv.params.sort_values(ascending=False))
# Out:
# --- O que mais correlaciona com o Ponto de Virada (IPV)? ---
# IPV    1.000000
# IPP    0.594514
# IEG    0.519948
# IDA    0.351948
# IAA    0.213953
# IPS    0.211527
# Name: IPV, dtype: float64
#
# --- PESO DOS COMPORTAMENTOS NO IPV ---
# R-quadrado: 57.75%
# const    0.574399
# IPP      0.530013
# IEG      0.251872
# IDA      0.071153
# IPS      0.058491
# IAA      0.040531
# dtype: float64

# %% [markdown]
# A análise indica que o Engajamento (IEG) é o principal impulsionador do Ponto de Virada (IPV), sugerindo que a constância e a participação nas atividades são os comportamentos que mais geram reconhecimento de evolução na metodologia Passos Mágicos. Diferente do INDE, onde o desempenho acadêmico (IDA) é protagonista, no IPV observa-se uma influência maior de fatores comportamentais e de autoavaliação (IAA), demonstrando que a 'virada' de chave do aluno acontece mais pela postura e esforço do que apenas pelo intelecto.

# %% [markdown]
# ### **8. Multidimensionalidade dos indicadores: Quais combinações de indicadores (IDA + IEG + IPS + IPP) elevam mais a nota global do aluno (INDE)?

# %%
df_indicadores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4044 entries, 0 to 4043
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IAN        2275 non-null   float64
#  1   IDA        2275 non-null   float64
#  2   IEG        2275 non-null   float64
#  3   IAA        2275 non-null   float64
#  4   IPS        2275 non-null   float64
#  5   IPP        2275 non-null   float64
#  6   IPV        2275 non-null   float64
#  7   Ano        4044 non-null   object
#  8   CATEG_IPP  4044 non-null   object
#  9   CATEG_IAN  2275 non-null   object
# dtypes: float64(7), object(3)
# memory usage: 316.1+ KB

# %%
def preparar_df(df_orig, colunas):
    colunas_existentes = [c for c in colunas if c in df_orig.columns]
    temp = df_orig[colunas_existentes].copy()
    for col in temp.columns:
        temp[col] = pd.to_numeric(temp[col], errors='coerce')
    temp.columns = [c.split('_')[0] for c in temp.columns]
    return temp

cols_2020 = ['INDE_2020', 'IDA_2020', 'IEG_2020', 'IPS_2020', 'IPP_2020']
cols_2021 = ['INDE_2021', 'IDA_2021', 'IEG_2021', 'IPS_2021', 'IPP_2021']
cols_2022 = ['INDE_2022', 'IDA_2022', 'IEG_2022', 'IPS_2022', 'IPP_2022']

df_analise_inde = pd.concat([
    preparar_df(df, cols_2020), 
    preparar_df(df, cols_2021), 
    preparar_df(df, cols_2022)
], axis=0).dropna()

X = df_analise_inde[['IDA', 'IEG', 'IPS', 'IPP']]
y = df_analise_inde['INDE']
X_const = sm.add_constant(X)
modelo = sm.OLS(y, X_const).fit()

df_analise_inde['IDA_Nivel'] = pd.qcut(df_analise_inde['IDA'], 3, labels=['Baixo', 'Médio', 'Alto'])
df_analise_inde['IEG_Nivel'] = pd.qcut(df_analise_inde['IEG'], 3, labels=['Baixo', 'Médio', 'Alto'])

tabela_impacto = df_analise_inde.pivot_table(values='INDE', index='IDA_Nivel', columns='IEG_Nivel', aggfunc='mean')

print("--- RESULTADO DA ANÁLISE DE ELEVAÇÃO ---")
print("\n1. Impacto Unitário (Quanto cada ponto em X aumenta o INDE):")
print(modelo.params[1:].sort_values(ascending=False))
# Out:
# --- RESULTADO DA ANÁLISE DE ELEVAÇÃO ---
#
# 1. Impacto Unitário (Quanto cada ponto em X aumenta o INDE):
# IDA    0.257383
# IEG    0.255966
# IPS    0.142289
# IPP    0.126866
# dtype: float64

# %% [markdown]
# O IDA foi o indicador que mais aumenta o INDE

# %% [markdown]
# ### **9. Previsão de risco com Machine Learning: Quais padrões nos indicadores permitem identificar alunos em risco antes de queda no desempenho ou aumento da defasagem? Construa um modelo preditivo que mostre uma probabilidade do aluno ou aluna entrar em risco de defasagem.**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.metrics import classification_report, confusion_matrix

if 'df' not in locals():
    print("ERRO: A variável 'df' não está definida.")
    print("Por favor, corre a célula onde carregas o ficheiro CSV (pd.read_csv...) antes de correr este código.")
else:
    def get_year_data(df_orig, year_input, year_target):
        cols_numericas = ['IAN', 'IDA', 'IEG', 'IPS', 'IPP', 'IPV', 'INDE']
        cols_in = [f'{c}_{year_input}' for c in cols_numericas]
        col_target = f'IAN_{year_target}'

        cols_existentes = [c for c in cols_in if c in df_orig.columns]
        if len(cols_existentes) < len(cols_numericas) or col_target not in df_orig.columns:
            return pd.DataFrame()
            
        data = df_orig[cols_existentes + [col_target]].copy()
        
        rename_map = {f'{c}_{year_input}': c for c in cols_numericas}
        rename_map[col_target] = 'IAN_TARGET'
        return data.rename(columns=rename_map)


    df_model = pd.concat([
        get_year_data(df, '2020', '2021'),
        get_year_data(df, '2021', '2022')
    ], axis=0).dropna()

    df_model['RISCO_DEFASAGEM'] = (df_model['IAN_TARGET'] <= 5).astype(int)

    X = df_model[['IDA', 'IEG', 'IPS', 'IPP', 'IPV', 'IAN', 'INDE']]
    y = df_model['RISCO_DEFASAGEM']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    train_data = pd.concat([X_train, y_train], axis=1)

    classe_0 = train_data[train_data.RISCO_DEFASAGEM == 0] 
    classe_1 = train_data[train_data.RISCO_DEFASAGEM == 1] 

    classe_0_upsampled = resample(classe_0, 
                                  replace=True,     
                                  n_samples=len(classe_1), 
                                  random_state=42)

    train_balanced = pd.concat([classe_1, classe_0_upsampled])

    X_train_bal = train_balanced.drop('RISCO_DEFASAGEM', axis=1)
    y_train_bal = train_balanced['RISCO_DEFASAGEM']

    print(f"Dados de Treino Balanceados: {y_train_bal.value_counts().to_dict()}")

    clf = RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42)
    clf.fit(X_train_bal, y_train_bal)

    y_pred = clf.predict(X_test)
    
    print("\n--- Relatório Final ---")
    print(classification_report(y_test, y_pred))

    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Greens',
                xticklabels=['Sem Risco', 'Com Risco'],
                yticklabels=['Sem Risco', 'Com Risco'])
    plt.title('Matriz de Confusão (Após Balanceamento)')
    plt.ylabel('Realidade')
    plt.xlabel('Previsão do Modelo')
    plt.show()

coeficientes = modelo.params.drop('const')
coeficientes = coeficientes.sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=coeficientes.values, y=coeficientes.index, palette='viridis')
plt.title('Peso de cada Indicador na Composição do INDE')
plt.xlabel('Importância (Coeficiente da Regressão)')
plt.ylabel('Indicador')
plt.show()
# Out:
# Dados de Treino Balanceados: {1: 428, 0: 428}
#
# --- Relatório Final ---
#               precision    recall  f1-score   support
#
#            0       0.58      0.57      0.57        88
#            1       0.80      0.81      0.80       187
#
#     accuracy                           0.73       275
#    macro avg       0.69      0.69      0.69       275
# weighted avg       0.73      0.73      0.73       275

# %% [markdown]
# O modelo preditivo desenvolvido atingiu uma eficácia de 81% (Recall) na identificação de alunos em risco de defasagem. Isso significa que a ferramenta é capaz de antecipar a vulnerabilidade em 8 de cada 10 alunos, permitindo intervenções preventivas.
#
# Embora o modelo apresente uma taxa moderada de falsos positivos (alertas de risco em alunos seguros), essa característica é benéfica no contexto pedagógico, pois prioriza a cautela ('pecar pelo excesso'), garantindo que o maior número possível de estudantes receba atenção e suporte antes que o desempenho caia efetivamente.

# %% [markdown]
# ### **10. Efetividade do programa: Os indicadores mostram melhora consistente ao longo do ciclo nas diferentes fases (Quartzo, Ágata, Ametista e Topázio), confirmando o impacto real do programa?**

# %%
def get_data_pedra(df_orig, year):
    col_inde = f'INDE_{year}'
    col_pedra = f'PEDRA_{year}'
    
    if col_inde not in df_orig.columns or col_pedra not in df_orig.columns:
        return pd.DataFrame()
    
    temp = df_orig[[col_inde, col_pedra]].copy()
    temp.columns = ['INDE', 'PEDRA']
    
    temp['INDE'] = temp['INDE'].astype(str).str.replace(',', '.')
    temp['INDE'] = pd.to_numeric(temp['INDE'], errors='coerce')
    temp['Ano'] = int(year)
    return temp

df_evolucao = pd.concat([
    get_data_pedra(df, '2020'),
    get_data_pedra(df, '2021'),
    get_data_pedra(df, '2022')
], axis=0).dropna()

ordem_pedras = ['Quartzo', 'Ágata', 'Ametista', 'Topázio']
df_evolucao = df_evolucao[df_evolucao['PEDRA'].isin(ordem_pedras)]

plt.figure(figsize=(12, 6))

sns.lineplot(data=df_evolucao, x='Ano', y='INDE', hue='PEDRA', 
             style='PEDRA', markers=True, dashes=False, 
             hue_order=ordem_pedras, palette='viridis', linewidth=2.5)

plt.title('Efetividade do Programa: Evolução do INDE por Fase (Pedra)', fontsize=14)
plt.ylabel('Desempenho Global (INDE)')
plt.xlabel('Ano do Ciclo')
plt.xticks([2020, 2021, 2022])
plt.grid(True, linestyle='--', alpha=0.5)

plt.legend(title='Fase (Pedra)', bbox_to_anchor=(1.02, 0.2), loc='center left', borderaxespad=0)

medias = df_evolucao.groupby(['Ano', 'PEDRA'])['INDE'].mean().reset_index()
for index, row in medias.iterrows():
    plt.text(row['Ano'], row['INDE'] + 0.15, f"{row['INDE']:.2f}", 
             color='black', ha='center', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()

pivot_table = medias.pivot(index='PEDRA', columns='Ano', values='INDE')
pivot_table = pivot_table.reindex(ordem_pedras)

if 2020 in pivot_table.columns and 2022 in pivot_table.columns:
    pivot_table['Melhora Total'] = pivot_table[2022] - pivot_table[2020]

print("\n--- Tabela de Variação de Desempenho (Médias do INDE) ---")
print(pivot_table)
# Out:
# --- Tabela de Variação de Desempenho (Médias do INDE) ---
# Ano           2020      2021      2022  Melhora Total
# PEDRA
# Quartzo   5.269935  4.526145  5.219319      -0.050616
# Ágata     6.767270  6.280949  6.605993      -0.161276
# Ametista  7.913472  7.537319  7.528436      -0.385035
# Topázio   8.843382  8.633752  8.366497      -0.476884

# %% [markdown]
# Os indicadores confirmam a efetividade do programa principalmente na sua capacidade de resiliência e resgate. Observa-se que a fase Quartzo (alunos com maiores dificuldades) sofreu uma queda brusca em 2021 (efeito pandemia), mas apresentou uma recuperação vigorosa em 2022, retornando aos patamares de 2020. Já as fases de excelência (Topázio), embora mantenham médias altas (acima de 8,3), apresentaram leve retração, indicando que o foco do programa no período foi bem-sucedido em evitar a evasão e recuperar o aprendizado dos alunos mais vulneráveis.

# %%
from sklearn.preprocessing import StandardScaler
import joblib

# 1. Criar e ajustar o Scaler (importante para o Streamlit não quebrar)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_bal)
X_test_scaled = scaler.transform(X_test)

# 2. Treinar o modelo com os dados escalados
clf = RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42)
clf.fit(X_train_scaled, y_train_bal)

# 3. Salvar os arquivos com os nomes que o seu Streamlit já busca
joblib.dump(clf, 'modelo_gb_pede.joblib') # Salvando o RandomForest com o nome que o app espera
joblib.dump(scaler, 'scaler_pede.joblib')

print("✅ Arquivos 'modelo_gb_pede.joblib' e 'scaler_pede.joblib' gerados com sucesso!")
# Out:
# ✅ Arquivos 'modelo_gb_pede.joblib' e 'scaler_pede.joblib' gerados com sucesso!
